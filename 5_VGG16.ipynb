# %% [markdown]
# # VGG16 Neural Network Analysis

# %% [markdown]
# ## Environment Setup

# %%
import pandas as pd
import tensorflow as tf
import os
import shutil
import numpy as np
from tensorflow import keras
from tensorflow.keras import optimizers
from keras import layers
from keras import models
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
CLASSES = ['Paul_Gauguin',
 'Edgar_Degas',
 'Vincent_van_Gogh',
 'Albrecht_Dürer',
 'Pablo_Picasso',
 'Titian',
 'Francisco_Goya',
 'Marc_Chagall',
 'Pierre-Auguste_Renoir',
 'Alfred_Sisley',
 'Rembrandt']

TRAIN_DIR = '/content/drive/Shareddrives/DeepLearning-ArtClassification/Data/Split-dataset/train'
TEST_DIR = '/content/drive/Shareddrives/DeepLearning-ArtClassification/Data/Split-dataset/test'
VAL_DIR = '/content/drive/Shareddrives/DeepLearning-ArtClassification/Data/Split-dataset/val'

IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
BATCH_SIZE = 32
RANDOM_SEED = 47
NUM_EPOCHS = 20
PATIENCE = 3

MODEL_DIR = "/content/drive/Shareddrives/DeepLearning-ArtClassification/Models/VGG16Weights"

if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

LOCAL_PATH = "/content/model"

if not os.path.exists(LOCAL_PATH):
    os.makedirs(LOCAL_PATH)

DROPOUT_PERC = 0.5

# %% [markdown]
# ##  Compute class weights

# %%
GENERAL_PATH="/content/drive/Shareddrives/DeepLearning-ArtClassification/Data/Split-dataset/train"

class_cardinality={}
for it in os.scandir(GENERAL_PATH):
    if it.is_dir():
      class_cardinality[it.name]=len(os.listdir(it.path))

df = pd.DataFrame(class_cardinality.items(), columns=['Name', 'Num_Paintings'])
df["Class_Weight"] = df.Num_Paintings.sum() / (len(CLASSES)*df.Num_Paintings)
CLASS_WEIGHTS = df['Class_Weight'].to_dict()
CLASS_WEIGHTS
# Out:
# {0: 1.258483452031839,
#  1: 0.556193297537493,
#  2: 0.44549903603737206,
#  3: 1.1925367209210005,
#  4: 0.889546935149541,
#  5: 1.5342185903983656,
#  6: 1.3452754142409316,
#  7: 1.6352749047359825,
#  8: 1.1620889748549323,
#  9: 1.508789552988448,
#  10: 1.4923000496770988}

# %% [markdown]
# ## Utility funciton to reuse snippet of code

# %%
from sklearn.utils import class_weight
def model_compiler(model, learning_rate = 0.001, my_loss = "sparse_categorical_crossentropy", my_optimizer = "Adam", my_metrics = "accuracy"):
  
  custom_opt = optimizers.Adam(learning_rate=learning_rate)
  
  model.compile(loss = my_loss, optimizer = custom_opt, metrics = [my_metrics])
  return model

def model_executor(model, model_name, train, validation, epoch_number = 20, patience = 2, class_weights=None):
  model_path = LOCAL_PATH + "/" + model_name + ".h5"
  callbacks = [
      tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience),
      keras.callbacks.ModelCheckpoint(filepath = model_path, monitor="val_loss", verbose=1, save_best_only=True)
  ]

  train_history = model.fit(train, validation_data = validation, epochs=epoch_number, callbacks = callbacks, class_weight=class_weights)

  shutil.copy(model_path, MODEL_DIR + "/" + model_name + ".h5")

  return model, train_history

def model_evaluator(model, test):
  model.evaluate(test)

  true_labels = np.concatenate([y for x, y in test], axis=0)
  pred_labels = model.predict(test)
  pred_labels = np.argmax(pred_labels, axis=-1)
  print(classification_report(true_labels, pred_labels, target_names = CLASSES))
  return pred_labels

def confusion_matrix_maker(model, test, pred_labels):

  true_labels = np.concatenate([y for x, y in test], axis=0)
  fig, ax = plt.subplots(figsize=(10, 10))
  ConfusionMatrixDisplay.from_predictions(true_labels, pred_labels, xticks_rotation='vertical', ax=ax, display_labels=CLASSES)

def plot_train_history(history):
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'val'], loc='upper left')
  plt.show()

def plot_model_structure(model, name):
    tf.keras.utils.plot_model(model, to_file=name+'.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Dataset Loading

# %%
training_images = tf.keras.preprocessing.image_dataset_from_directory(
    TRAIN_DIR,
    labels='inferred',
    batch_size=BATCH_SIZE,
    color_mode='rgb',
    image_size=(IMAGE_HEIGHT,IMAGE_WIDTH),
    interpolation='bilinear',
    shuffle=True,
    seed=RANDOM_SEED
)

test_images = tf.keras.preprocessing.image_dataset_from_directory(
    TEST_DIR,
    labels='inferred',
    batch_size=BATCH_SIZE,
    color_mode='rgb',
    image_size=(IMAGE_HEIGHT,IMAGE_WIDTH),
    interpolation='bilinear',
    shuffle=False,
    seed=RANDOM_SEED
)


val_images = tf.keras.preprocessing.image_dataset_from_directory(
    VAL_DIR,
    labels='inferred',
    batch_size=BATCH_SIZE,
    color_mode='rgb',
    image_size=(IMAGE_HEIGHT,IMAGE_WIDTH),
    interpolation='bilinear',
    shuffle=True,
    seed=RANDOM_SEED
)
# Out:
# Found 3004 files belonging to 11 classes.
# Found 656 files belonging to 11 classes.
# Found 639 files belonging to 11 classes.

# %% [markdown]
# ## VGG16 with custom classifier

# %%
vgg = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

vgg.trainable = False
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = vgg(x)

x = layers.Flatten(name='flatten')(x)

x = layers.Dense(512,activation='relu', name='classifier_hidden_1')(x)
x = layers.Dense(512,activation='relu', name='classifier_hidden_2')(x)

output = layers.Dense(len(CLASSES), activation='softmax')(x)
model = tf.keras.models.Model(inputs=inputs, outputs=output, name="VGG16_test")


model = model_compiler(model, learning_rate=0.0005)
model.summary()
# Out:
# Model: "VGG16_test"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_4   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_4 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  classifier_hidden_1 (Dense)  (None, 512)              12845568
#
#  classifier_hidden_2 (Dense)  (None, 516)              264708
#
#  dense_4 (Dense)             (None, 11)                5687
#
# =================================================================
# Total params: 27,830,651
# Trainable params: 13,115,963
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model, history = model_executor(model, "NoDropout", training_images, val_images, NUM_EPOCHS, PATIENCE, CLASS_WEIGHTS)
# Out:
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 4.6055 - accuracy: 0.5406
# Epoch 1: val_loss improved from inf to 1.22061, saving model to /content/model/NoDropout_test.h5
# 94/94 [==============================] - 22s 222ms/step - loss: 4.6055 - accuracy: 0.5406 - val_loss: 1.2206 - val_accuracy: 0.6729
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3228 - accuracy: 0.9101
# Epoch 2: val_loss did not improve from 1.22061
# 94/94 [==============================] - 21s 218ms/step - loss: 0.3228 - accuracy: 0.9101 - val_loss: 1.2760 - val_accuracy: 0.7543
# Epoch 3/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9780
# Epoch 3: val_loss improved from 1.22061 to 1.21038, saving model to /content/model/NoDropout_test.h5
# 94/94 [==============================] - 21s 222ms/step - loss: 0.0740 - accuracy: 0.9780 - val_loss: 1.2104 - val_accuracy: 0.7559
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9977
# Epoch 4: val_loss improved from 1.21038 to 1.08662, saving model to /content/model/NoDropout_test.h5
# 94/94 [==============================] - 22s 229ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 1.0866 - val_accuracy: 0.7700
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 9.8459e-04 - accuracy: 1.0000
# Epoch 5: val_loss did not improve from 1.08662
# 94/94 [==============================] - 20s 213ms/step - loss: 9.8459e-04 - accuracy: 1.0000 - val_loss: 1.0893 - val_accuracy: 0.7809
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 4.0060e-04 - accuracy: 1.0000
# Epoch 6: val_loss did not improve from 1.08662
# 94/94 [==============================] - 20s 212ms/step - loss: 4.0060e-04 - accuracy: 1.0000 - val_loss: 1.1188 - val_accuracy: 0.7778
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 2.8293e-04 - accuracy: 1.0000
# Epoch 7: val_loss did not improve from 1.08662
# 94/94 [==============================] - 21s 215ms/step - loss: 2.8293e-04 - accuracy: 1.0000 - val_loss: 1.1157 - val_accuracy: 0.7778

# %% [markdown]
# Plots of accuracy and loss during training, these can help to recognize overfitting

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 82s 4s/step - loss: 1.0305 - accuracy: 0.7973
# 21/21 [==============================] - 4s 169ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.89      0.94      0.91        50
#           Edgar_Degas       0.85      0.72      0.78        40
#      Vincent_van_Gogh       0.84      0.90      0.87       106
#        Albrecht_Dürer       0.71      0.67      0.69        45
#         Pablo_Picasso       0.90      0.70      0.79        37
#                Titian       0.76      0.79      0.77        67
#        Francisco_Goya       0.70      0.65      0.67        48
#          Marc_Chagall       0.81      0.67      0.73        51
# Pierre-Auguste_Renoir       0.86      0.78      0.82        40
#         Alfred_Sisley       0.68      0.77      0.72        39
#             Rembrandt       0.79      0.88      0.83       133
#
#              accuracy                           0.80       656
#             macro avg       0.80      0.77      0.78       656
#          weighted avg       0.80      0.80      0.80       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %%
plot_model_structure(model, "VGG_no_dropout")

# %% [markdown]
# ## VGG16 with Dropout

# %%
vgg = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

vgg.trainable = False
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# We decided to add a dropout layer after each layer to prevent overfitting

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = vgg(x)


x = layers.Flatten(name='flatten')(x)

x = layers.Dense(1024,activation='relu', name='classifier_hidden_1')(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(512,activation='relu', name='classifier_hidden_2')(x)
#x = layers.Dropout(0.3)(x)

output = layers.Dense(len(CLASSES), activation='softmax')(x)
model = tf.keras.models.Model(inputs=inputs, outputs=output, name="VGG16_Dropout")


model = model_compiler(model, learning_rate=0.0008)
model.summary()
# Out:
# Model: "VGG16_Dropout"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_7   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_7 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  classifier_hidden_1 (Dense)  (None, 1024)             25691136
#
#  dropout_9 (Dropout)         (None, 1024)              0
#
#  classifier_hidden_2 (Dense)  (None, 512)              524800
#
#  dense_7 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 40,936,267
# Trainable params: 26,221,579
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model, history = model_executor(model, "Dropout", training_images, val_images, 20, 5, CLASS_WEIGHTS)
# Out:
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 9.6630 - accuracy: 0.5053
# Epoch 1: val_loss improved from inf to 1.97403, saving model to /content/model/Dropout.h5
# 94/94 [==============================] - 23s 233ms/step - loss: 9.6630 - accuracy: 0.5053 - val_loss: 1.9740 - val_accuracy: 0.6808
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 1.6995 - accuracy: 0.7780
# Epoch 2: val_loss did not improve from 1.97403
# 94/94 [==============================] - 20s 211ms/step - loss: 1.6995 - accuracy: 0.7780 - val_loss: 2.2193 - val_accuracy: 0.6948
# Epoch 3/20
# 94/94 [==============================] - ETA: 0s - loss: 0.9072 - accuracy: 0.8562
# Epoch 3: val_loss improved from 1.97403 to 1.96056, saving model to /content/model/Dropout.h5
# 94/94 [==============================] - 22s 229ms/step - loss: 0.9072 - accuracy: 0.8562 - val_loss: 1.9606 - val_accuracy: 0.7512
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 0.7331 - accuracy: 0.8978
# Epoch 4: val_loss did not improve from 1.96056
# 94/94 [==============================] - 20s 212ms/step - loss: 0.7331 - accuracy: 0.8978 - val_loss: 2.4635 - val_accuracy: 0.7340
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 0.5941 - accuracy: 0.9218
# Epoch 5: val_loss did not improve from 1.96056
# 94/94 [==============================] - 20s 210ms/step - loss: 0.5941 - accuracy: 0.9218 - val_loss: 2.5916 - val_accuracy: 0.7512
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 0.8724 - accuracy: 0.9081
# Epoch 6: val_loss did not improve from 1.96056
# 94/94 [==============================] - 20s 211ms/step - loss: 0.8724 - accuracy: 0.9081 - val_loss: 3.7062 - val_accuracy: 0.7293
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 0.8039 - accuracy: 0.9241
# Epoch 7: val_loss did not improve from 1.96056
# 94/94 [==============================] - 20s 212ms/step - loss: 0.8039 - accuracy: 0.9241 - val_loss: 3.0859 - val_accuracy: 0.7433
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 0.8235 - accuracy: 0.9261
# Epoch 8: val_loss did not improve from 1.96056
# 94/94 [==============================] - 20s 212ms/step - loss: 0.8235 - accuracy: 0.9261 - val_loss: 3.2419 - val_accuracy: 0.7246

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 4s 171ms/step - loss: 3.1069 - accuracy: 0.7241
# 21/21 [==============================] - 4s 174ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.94      0.64      0.76        50
#           Edgar_Degas       0.70      0.88      0.78        40
#      Vincent_van_Gogh       0.90      0.77      0.83       106
#        Albrecht_Dürer       0.67      0.69      0.68        45
#         Pablo_Picasso       0.54      0.78      0.64        37
#                Titian       0.67      0.73      0.70        67
#        Francisco_Goya       0.81      0.27      0.41        48
#          Marc_Chagall       0.57      0.80      0.67        51
# Pierre-Auguste_Renoir       0.67      0.78      0.72        40
#         Alfred_Sisley       0.81      0.56      0.67        39
#             Rembrandt       0.75      0.83      0.79       133
#
#              accuracy                           0.72       656
#             macro avg       0.73      0.70      0.69       656
#          weighted avg       0.75      0.72      0.72       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %%
plot_model_structure(model, "VGG_dropout")

# %% [markdown]
# ## VGG16 Batch Normalization

# %%
vgg = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

vgg.trainable = False
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# We decided to add a dropout layer after each layer to prevent overfitting

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = vgg(x)


x = layers.Flatten(name='flatten')(x)

x = layers.Dense(1024,activation='relu', name='classifier_hidden_1')(x)
x = layers.BatchNormalization(epsilon = 1e-4)(x)
x = layers.Dense(512,activation='relu', name='classifier_hidden_2')(x)
x = layers.BatchNormalization(epsilon = 1e-4)(x)

output = layers.Dense(len(CLASSES), activation='softmax')(x)
model = tf.keras.models.Model(inputs=inputs, outputs=output, name="VGG16_test")


model = model_compiler(model, learning_rate=0.0008)
model.summary()
# Out:
# Model: "VGG16_test"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  classifier_hidden_1 (Dense)  (None, 1024)             25691136
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  classifier_hidden_2 (Dense)  (None, 512)              524800
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 40,942,411
# Trainable params: 26,224,651
# Non-trainable params: 14,717,760
# _________________________________________________________________

# %%
model, history = model_executor(model, "VGG16_test", training_images, val_images, 20, 5, CLASS_WEIGHTS)
# Out:
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 1.3639 - accuracy: 0.6638
# Epoch 1: val_loss improved from inf to 1.24219, saving model to /content/model/VGG16_test.h5
# 94/94 [==============================] - 1467s 14s/step - loss: 1.3639 - accuracy: 0.6638 - val_loss: 1.2422 - val_accuracy: 0.7246
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9634
# Epoch 2: val_loss improved from 1.24219 to 0.69896, saving model to /content/model/VGG16_test.h5
# 94/94 [==============================] - 20s 205ms/step - loss: 0.1241 - accuracy: 0.9634 - val_loss: 0.6990 - val_accuracy: 0.8091
# Epoch 3/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9953
# Epoch 3: val_loss improved from 0.69896 to 0.62091, saving model to /content/model/VGG16_test.h5
# 94/94 [==============================] - 18s 187ms/step - loss: 0.0265 - accuracy: 0.9953 - val_loss: 0.6209 - val_accuracy: 0.8059
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9983
# Epoch 4: val_loss did not improve from 0.62091
# 94/94 [==============================] - 17s 179ms/step - loss: 0.0099 - accuracy: 0.9983 - val_loss: 0.6294 - val_accuracy: 0.8153
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9997
# Epoch 5: val_loss improved from 0.62091 to 0.60892, saving model to /content/model/VGG16_test.h5
# 94/94 [==============================] - 19s 193ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.6089 - val_accuracy: 0.8247
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 6: val_loss improved from 0.60892 to 0.59950, saving model to /content/model/VGG16_test.h5
# 94/94 [==============================] - 18s 192ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5995 - val_accuracy: 0.8279
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 7: val_loss improved from 0.59950 to 0.59871, saving model to /content/model/VGG16_test.h5
# 94/94 [==============================] - 19s 193ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5987 - val_accuracy: 0.8357
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 8: val_loss did not improve from 0.59871
# 94/94 [==============================] - 17s 178ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6037 - val_accuracy: 0.8326
# Epoch 9/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 0.59871
# 94/94 [==============================] - 17s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6151 - val_accuracy: 0.8279
# Epoch 10/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9987
# Epoch 10: val_loss did not improve from 0.59871
# 94/94 [==============================] - 17s 178ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.6375 - val_accuracy: 0.8200
# Epoch 11/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 0.59871
# 94/94 [==============================] - 19s 200ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6386 - val_accuracy: 0.8263
# Epoch 12/20
# 94/94 [==============================] - ETA: 0s - loss: 6.7620e-04 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 0.59871
# 94/94 [==============================] - 17s 179ms/step - loss: 6.7620e-04 - accuracy: 1.0000 - val_loss: 0.6382 - val_accuracy: 0.8310

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 268s 13s/step - loss: 0.6684 - accuracy: 0.8247
# 21/21 [==============================] - 3s 137ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.92      0.96      0.94        50
#           Edgar_Degas       0.78      0.88      0.82        40
#      Vincent_van_Gogh       0.92      0.90      0.91       106
#        Albrecht_Dürer       0.79      0.69      0.74        45
#         Pablo_Picasso       0.92      0.65      0.76        37
#                Titian       0.78      0.76      0.77        67
#        Francisco_Goya       0.84      0.75      0.79        48
#          Marc_Chagall       0.76      0.69      0.72        51
# Pierre-Auguste_Renoir       0.82      0.90      0.86        40
#         Alfred_Sisley       0.72      0.72      0.72        39
#             Rembrandt       0.79      0.92      0.85       133
#
#              accuracy                           0.82       656
#             macro avg       0.82      0.80      0.81       656
#          weighted avg       0.83      0.82      0.82       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %%
plot_model_structure(model, "VGG16_test")

# %% [markdown]
# ## VGG16 Batch Normalization + L2 Regularization

# %%
vgg = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

vgg.trainable = False
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# We decided to add a dropout layer after each layer to prevent overfitting

# %%
from tensorflow.keras import regularizers

inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = vgg(x)


x = layers.Flatten(name='flatten')(x)

x = layers.Dense(1024,activation='relu', name='classifier_hidden_1', kernel_regularizer=regularizers.L2(l2=1e-4))(x)
x = layers.BatchNormalization(epsilon = 1e-4)(x)
x = layers.Dense(512,activation='relu', name='classifier_hidden_2', kernel_regularizer=regularizers.L2(l2=1e-4))(x)
x = layers.BatchNormalization(epsilon = 1e-4)(x)

output = layers.Dense(len(CLASSES), activation='softmax')(x)
model = tf.keras.models.Model(inputs=inputs, outputs=output, name="VGG16_test2")


model = model_compiler(model, learning_rate=0.0008)
model.summary()
# Out:
# Model: "VGG16_test2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_5   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_5 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  classifier_hidden_1 (Dense)  (None, 1024)             25691136
#
#  batch_normalization_10 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  classifier_hidden_2 (Dense)  (None, 512)              524800
#
#  batch_normalization_11 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_5 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 40,942,411
# Trainable params: 26,224,651
# Non-trainable params: 14,717,760
# _________________________________________________________________

# %%
model, history = model_executor(model, "VGG16_test2", training_images, val_images, 20, 5, CLASS_WEIGHTS)
# Out:
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 1.6940 - accuracy: 0.6505
# Epoch 1: val_loss improved from inf to 1.84993, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 21s 196ms/step - loss: 1.6940 - accuracy: 0.6505 - val_loss: 1.8499 - val_accuracy: 0.6620
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 0.4548 - accuracy: 0.9687
# Epoch 2: val_loss improved from 1.84993 to 0.99440, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 19s 199ms/step - loss: 0.4548 - accuracy: 0.9687 - val_loss: 0.9944 - val_accuracy: 0.8122
# Epoch 3/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3628 - accuracy: 0.9953
# Epoch 3: val_loss improved from 0.99440 to 0.96145, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 18s 191ms/step - loss: 0.3628 - accuracy: 0.9953 - val_loss: 0.9614 - val_accuracy: 0.8059
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.9980
# Epoch 4: val_loss improved from 0.96145 to 0.89751, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 20s 211ms/step - loss: 0.3386 - accuracy: 0.9980 - val_loss: 0.8975 - val_accuracy: 0.8263
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3239 - accuracy: 0.9993
# Epoch 5: val_loss improved from 0.89751 to 0.87298, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 18s 192ms/step - loss: 0.3239 - accuracy: 0.9993 - val_loss: 0.8730 - val_accuracy: 0.8310
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.9997
# Epoch 6: val_loss improved from 0.87298 to 0.86091, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 19s 195ms/step - loss: 0.3097 - accuracy: 0.9997 - val_loss: 0.8609 - val_accuracy: 0.8310
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2975 - accuracy: 0.9987
# Epoch 7: val_loss did not improve from 0.86091
# 94/94 [==============================] - 17s 180ms/step - loss: 0.2975 - accuracy: 0.9987 - val_loss: 0.8922 - val_accuracy: 0.8232
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.9997
# Epoch 8: val_loss did not improve from 0.86091
# 94/94 [==============================] - 17s 179ms/step - loss: 0.2840 - accuracy: 0.9997 - val_loss: 0.8772 - val_accuracy: 0.8263
# Epoch 9/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 0.86091
# 94/94 [==============================] - 17s 178ms/step - loss: 0.2696 - accuracy: 1.0000 - val_loss: 0.8666 - val_accuracy: 0.8185
# Epoch 10/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 1.0000
# Epoch 10: val_loss improved from 0.86091 to 0.85847, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 18s 192ms/step - loss: 0.2567 - accuracy: 1.0000 - val_loss: 0.8585 - val_accuracy: 0.8279
# Epoch 11/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2438 - accuracy: 1.0000
# Epoch 11: val_loss improved from 0.85847 to 0.83519, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 19s 194ms/step - loss: 0.2438 - accuracy: 1.0000 - val_loss: 0.8352 - val_accuracy: 0.8326
# Epoch 12/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 1.0000
# Epoch 12: val_loss improved from 0.83519 to 0.82273, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 18s 192ms/step - loss: 0.2305 - accuracy: 1.0000 - val_loss: 0.8227 - val_accuracy: 0.8341
# Epoch 13/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.82273 to 0.81057, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 19s 194ms/step - loss: 0.2178 - accuracy: 1.0000 - val_loss: 0.8106 - val_accuracy: 0.8341
# Epoch 14/20
# 94/94 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.81057 to 0.80226, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 18s 192ms/step - loss: 0.2054 - accuracy: 1.0000 - val_loss: 0.8023 - val_accuracy: 0.8294
# Epoch 15/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.80226 to 0.80160, saving model to /content/model/VGG16_test2.h5
# 94/94 [==============================] - 18s 192ms/step - loss: 0.1934 - accuracy: 1.0000 - val_loss: 0.8016 - val_accuracy: 0.8310
# Epoch 16/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9983
# Epoch 16: val_loss did not improve from 0.80160
# 94/94 [==============================] - 17s 179ms/step - loss: 0.1917 - accuracy: 0.9983 - val_loss: 1.0527 - val_accuracy: 0.8028
# Epoch 17/20
# 94/94 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.9141
# Epoch 17: val_loss did not improve from 0.80160
# 94/94 [==============================] - 17s 179ms/step - loss: 0.5955 - accuracy: 0.9141 - val_loss: 3.0235 - val_accuracy: 0.6573
# Epoch 18/20
# 94/94 [==============================] - ETA: 0s - loss: 1.1035 - accuracy: 0.8512
# Epoch 18: val_loss did not improve from 0.80160
# 94/94 [==============================] - 18s 180ms/step - loss: 1.1035 - accuracy: 0.8512 - val_loss: 1.8024 - val_accuracy: 0.7371
# Epoch 19/20
# 94/94 [==============================] - ETA: 0s - loss: 0.7338 - accuracy: 0.9640
# Epoch 19: val_loss did not improve from 0.80160
# 94/94 [==============================] - 17s 180ms/step - loss: 0.7338 - accuracy: 0.9640 - val_loss: 1.3497 - val_accuracy: 0.8013
# Epoch 20/20
# 94/94 [==============================] - ETA: 0s - loss: 0.6169 - accuracy: 0.9923
# Epoch 20: val_loss did not improve from 0.80160
# 94/94 [==============================] - 19s 201ms/step - loss: 0.6169 - accuracy: 0.9923 - val_loss: 1.2286 - val_accuracy: 0.8153

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 3s 129ms/step - loss: 1.2527 - accuracy: 0.8186
# 21/21 [==============================] - 3s 131ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.91      0.96      0.93        50
#           Edgar_Degas       0.82      0.70      0.76        40
#      Vincent_van_Gogh       0.92      0.88      0.90       106
#        Albrecht_Dürer       0.78      0.71      0.74        45
#         Pablo_Picasso       0.93      0.73      0.82        37
#                Titian       0.78      0.79      0.79        67
#        Francisco_Goya       0.75      0.69      0.72        48
#          Marc_Chagall       0.79      0.73      0.76        51
# Pierre-Auguste_Renoir       0.76      0.93      0.83        40
#         Alfred_Sisley       0.84      0.69      0.76        39
#             Rembrandt       0.77      0.92      0.84       133
#
#              accuracy                           0.82       656
#             macro avg       0.82      0.79      0.80       656
#          weighted avg       0.82      0.82      0.82       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %%
plot_model_structure(model, "VGG16_test2")

# %% [markdown]
# ## VGG16 Batch Normalization + Dropout

# %%
vgg = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)

vgg.trainable = False
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# We decided to add a dropout layer after each layer to prevent overfitting

# %%
from tensorflow.keras import regularizers

inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = vgg(x)


x = layers.Flatten(name='flatten')(x)

x = layers.Dense(512,activation='relu', name='classifier_hidden_1')(x)
x = layers.Dropout(0.4)(x)
x = layers.BatchNormalization(epsilon = 1e-4)(x)
x = layers.Dense(256,activation='relu', name='classifier_hidden_2')(x)
x = layers.Dropout(0.4)(x)
x = layers.BatchNormalization(epsilon = 1e-4)(x)

output = layers.Dense(len(CLASSES), activation='softmax')(x)
model = tf.keras.models.Model(inputs=inputs, outputs=output, name="VGG16_Batch_Dropout")


model = model_compiler(model, learning_rate=0.00001)
model.summary()
# Out:
# Model: "VGG16_test3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  classifier_hidden_1 (Dense)  (None, 512)              12845568
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  classifier_hidden_2 (Dense)  (None, 256)              131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense (Dense)               (None, 11)                2827
#
# =================================================================
# Total params: 27,697,483
# Trainable params: 12,981,259
# Non-trainable params: 14,716,224
# _________________________________________________________________

# %%
model, history = model_executor(model, "VGG16_Batch_Dropout", training_images, val_images, 100, 20, CLASS_WEIGHTS)
# Out:
# Epoch 1/100
# 94/94 [==============================] - ETA: 0s - loss: 3.5490 - accuracy: 0.1079
# Epoch 1: val_loss improved from inf to 2.27128, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 590s 6s/step - loss: 3.5490 - accuracy: 0.1079 - val_loss: 2.2713 - val_accuracy: 0.2175
# Epoch 2/100
# 94/94 [==============================] - ETA: 0s - loss: 2.9799 - accuracy: 0.1874
# Epoch 2: val_loss improved from 2.27128 to 1.91327, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 16s 167ms/step - loss: 2.9799 - accuracy: 0.1874 - val_loss: 1.9133 - val_accuracy: 0.3740
# Epoch 3/100
# 94/94 [==============================] - ETA: 0s - loss: 2.5357 - accuracy: 0.2840
# Epoch 3: val_loss improved from 1.91327 to 1.72346, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 16s 170ms/step - loss: 2.5357 - accuracy: 0.2840 - val_loss: 1.7235 - val_accuracy: 0.4648
# Epoch 4/100
# 94/94 [==============================] - ETA: 0s - loss: 2.2217 - accuracy: 0.3602
# Epoch 4: val_loss improved from 1.72346 to 1.58600, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 176ms/step - loss: 2.2217 - accuracy: 0.3602 - val_loss: 1.5860 - val_accuracy: 0.5227
# Epoch 5/100
# 94/94 [==============================] - ETA: 0s - loss: 2.0297 - accuracy: 0.4091
# Epoch 5: val_loss improved from 1.58600 to 1.46513, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 177ms/step - loss: 2.0297 - accuracy: 0.4091 - val_loss: 1.4651 - val_accuracy: 0.5775
# Epoch 6/100
# 94/94 [==============================] - ETA: 0s - loss: 1.7831 - accuracy: 0.4724
# Epoch 6: val_loss improved from 1.46513 to 1.37591, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 19s 201ms/step - loss: 1.7831 - accuracy: 0.4724 - val_loss: 1.3759 - val_accuracy: 0.5962
# Epoch 7/100
# 94/94 [==============================] - ETA: 0s - loss: 1.5922 - accuracy: 0.5233
# Epoch 7: val_loss improved from 1.37591 to 1.30342, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 19s 203ms/step - loss: 1.5922 - accuracy: 0.5233 - val_loss: 1.3034 - val_accuracy: 0.6228
# Epoch 8/100
# 94/94 [==============================] - ETA: 0s - loss: 1.4414 - accuracy: 0.5732
# Epoch 8: val_loss improved from 1.30342 to 1.25291, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 20s 204ms/step - loss: 1.4414 - accuracy: 0.5732 - val_loss: 1.2529 - val_accuracy: 0.6338
# Epoch 9/100
# 94/94 [==============================] - ETA: 0s - loss: 1.3535 - accuracy: 0.5982
# Epoch 9: val_loss improved from 1.25291 to 1.20422, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 1.3535 - accuracy: 0.5982 - val_loss: 1.2042 - val_accuracy: 0.6401
# Epoch 10/100
# 94/94 [==============================] - ETA: 0s - loss: 1.2137 - accuracy: 0.6325
# Epoch 10: val_loss improved from 1.20422 to 1.16171, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 1.2137 - accuracy: 0.6325 - val_loss: 1.1617 - val_accuracy: 0.6573
# Epoch 11/100
# 94/94 [==============================] - ETA: 0s - loss: 1.1229 - accuracy: 0.6711
# Epoch 11: val_loss improved from 1.16171 to 1.11654, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 1.1229 - accuracy: 0.6711 - val_loss: 1.1165 - val_accuracy: 0.6667
# Epoch 12/100
# 94/94 [==============================] - ETA: 0s - loss: 1.0409 - accuracy: 0.6974
# Epoch 12: val_loss improved from 1.11654 to 1.08589, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 182ms/step - loss: 1.0409 - accuracy: 0.6974 - val_loss: 1.0859 - val_accuracy: 0.6745
# Epoch 13/100
# 94/94 [==============================] - ETA: 0s - loss: 0.9446 - accuracy: 0.7190
# Epoch 13: val_loss improved from 1.08589 to 1.05523, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 20s 204ms/step - loss: 0.9446 - accuracy: 0.7190 - val_loss: 1.0552 - val_accuracy: 0.6917
# Epoch 14/100
# 94/94 [==============================] - ETA: 0s - loss: 0.9130 - accuracy: 0.7294
# Epoch 14: val_loss improved from 1.05523 to 1.03141, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 186ms/step - loss: 0.9130 - accuracy: 0.7294 - val_loss: 1.0314 - val_accuracy: 0.6964
# Epoch 15/100
# 94/94 [==============================] - ETA: 0s - loss: 0.8042 - accuracy: 0.7756
# Epoch 15: val_loss improved from 1.03141 to 1.00668, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.8042 - accuracy: 0.7756 - val_loss: 1.0067 - val_accuracy: 0.7042
# Epoch 16/100
# 94/94 [==============================] - ETA: 0s - loss: 0.7710 - accuracy: 0.7820
# Epoch 16: val_loss improved from 1.00668 to 0.98516, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.7710 - accuracy: 0.7820 - val_loss: 0.9852 - val_accuracy: 0.7121
# Epoch 17/100
# 94/94 [==============================] - ETA: 0s - loss: 0.7326 - accuracy: 0.7916
# Epoch 17: val_loss improved from 0.98516 to 0.96323, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 182ms/step - loss: 0.7326 - accuracy: 0.7916 - val_loss: 0.9632 - val_accuracy: 0.7293
# Epoch 18/100
# 94/94 [==============================] - ETA: 0s - loss: 0.6809 - accuracy: 0.8176
# Epoch 18: val_loss improved from 0.96323 to 0.94409, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 20s 203ms/step - loss: 0.6809 - accuracy: 0.8176 - val_loss: 0.9441 - val_accuracy: 0.7277
# Epoch 19/100
# 94/94 [==============================] - ETA: 0s - loss: 0.6072 - accuracy: 0.8356
# Epoch 19: val_loss improved from 0.94409 to 0.92668, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.6072 - accuracy: 0.8356 - val_loss: 0.9267 - val_accuracy: 0.7418
# Epoch 20/100
# 94/94 [==============================] - ETA: 0s - loss: 0.5779 - accuracy: 0.8432
# Epoch 20: val_loss improved from 0.92668 to 0.90904, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.5779 - accuracy: 0.8432 - val_loss: 0.9090 - val_accuracy: 0.7418
# Epoch 21/100
# 94/94 [==============================] - ETA: 0s - loss: 0.5374 - accuracy: 0.8612
# Epoch 21: val_loss improved from 0.90904 to 0.89531, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.5374 - accuracy: 0.8612 - val_loss: 0.8953 - val_accuracy: 0.7480
# Epoch 22/100
# 94/94 [==============================] - ETA: 0s - loss: 0.5029 - accuracy: 0.8685
# Epoch 22: val_loss improved from 0.89531 to 0.88109, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 19s 203ms/step - loss: 0.5029 - accuracy: 0.8685 - val_loss: 0.8811 - val_accuracy: 0.7543
# Epoch 23/100
# 94/94 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.8742
# Epoch 23: val_loss improved from 0.88109 to 0.86976, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.4939 - accuracy: 0.8742 - val_loss: 0.8698 - val_accuracy: 0.7606
# Epoch 24/100
# 94/94 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8812
# Epoch 24: val_loss improved from 0.86976 to 0.85939, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.4759 - accuracy: 0.8812 - val_loss: 0.8594 - val_accuracy: 0.7559
# Epoch 25/100
# 94/94 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.8888
# Epoch 25: val_loss improved from 0.85939 to 0.84160, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.4298 - accuracy: 0.8888 - val_loss: 0.8416 - val_accuracy: 0.7668
# Epoch 26/100
# 94/94 [==============================] - ETA: 0s - loss: 0.4124 - accuracy: 0.9005
# Epoch 26: val_loss improved from 0.84160 to 0.83249, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 182ms/step - loss: 0.4124 - accuracy: 0.9005 - val_loss: 0.8325 - val_accuracy: 0.7731
# Epoch 27/100
# 94/94 [==============================] - ETA: 0s - loss: 0.3767 - accuracy: 0.9198
# Epoch 27: val_loss improved from 0.83249 to 0.82373, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.3767 - accuracy: 0.9198 - val_loss: 0.8237 - val_accuracy: 0.7715
# Epoch 28/100
# 94/94 [==============================] - ETA: 0s - loss: 0.3570 - accuracy: 0.9254
# Epoch 28: val_loss improved from 0.82373 to 0.81498, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.3570 - accuracy: 0.9254 - val_loss: 0.8150 - val_accuracy: 0.7715
# Epoch 29/100
# 94/94 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.9224
# Epoch 29: val_loss improved from 0.81498 to 0.80522, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.3294 - accuracy: 0.9224 - val_loss: 0.8052 - val_accuracy: 0.7778
# Epoch 30/100
# 94/94 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.9301
# Epoch 30: val_loss improved from 0.80522 to 0.79824, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.3097 - accuracy: 0.9301 - val_loss: 0.7982 - val_accuracy: 0.7809
# Epoch 31/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2966 - accuracy: 0.9381
# Epoch 31: val_loss improved from 0.79824 to 0.78875, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.2966 - accuracy: 0.9381 - val_loss: 0.7888 - val_accuracy: 0.7793
# Epoch 32/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.9377
# Epoch 32: val_loss improved from 0.78875 to 0.78235, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 182ms/step - loss: 0.2874 - accuracy: 0.9377 - val_loss: 0.7824 - val_accuracy: 0.7825
# Epoch 33/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.9471
# Epoch 33: val_loss improved from 0.78235 to 0.77701, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.2732 - accuracy: 0.9471 - val_loss: 0.7770 - val_accuracy: 0.7872
# Epoch 34/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.9524
# Epoch 34: val_loss improved from 0.77701 to 0.77202, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.2701 - accuracy: 0.9524 - val_loss: 0.7720 - val_accuracy: 0.7903
# Epoch 35/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9487
# Epoch 35: val_loss improved from 0.77202 to 0.76622, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.2597 - accuracy: 0.9487 - val_loss: 0.7662 - val_accuracy: 0.7887
# Epoch 36/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.9521
# Epoch 36: val_loss improved from 0.76622 to 0.75672, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 181ms/step - loss: 0.2466 - accuracy: 0.9521 - val_loss: 0.7567 - val_accuracy: 0.7903
# Epoch 37/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9624
# Epoch 37: val_loss improved from 0.75672 to 0.74887, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 20s 204ms/step - loss: 0.2220 - accuracy: 0.9624 - val_loss: 0.7489 - val_accuracy: 0.7919
# Epoch 38/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2077 - accuracy: 0.9724
# Epoch 38: val_loss improved from 0.74887 to 0.74410, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.2077 - accuracy: 0.9724 - val_loss: 0.7441 - val_accuracy: 0.7872
# Epoch 39/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9667
# Epoch 39: val_loss improved from 0.74410 to 0.73942, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 20s 205ms/step - loss: 0.1936 - accuracy: 0.9667 - val_loss: 0.7394 - val_accuracy: 0.7934
# Epoch 40/100
# 94/94 [==============================] - ETA: 0s - loss: 0.2004 - accuracy: 0.9657
# Epoch 40: val_loss improved from 0.73942 to 0.73528, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.2004 - accuracy: 0.9657 - val_loss: 0.7353 - val_accuracy: 0.7919
# Epoch 41/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9684
# Epoch 41: val_loss improved from 0.73528 to 0.72803, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 19s 203ms/step - loss: 0.1857 - accuracy: 0.9684 - val_loss: 0.7280 - val_accuracy: 0.7934
# Epoch 42/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 0.9710
# Epoch 42: val_loss improved from 0.72803 to 0.72018, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.1768 - accuracy: 0.9710 - val_loss: 0.7202 - val_accuracy: 0.7950
# Epoch 43/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9790
# Epoch 43: val_loss improved from 0.72018 to 0.71660, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.1540 - accuracy: 0.9790 - val_loss: 0.7166 - val_accuracy: 0.7950
# Epoch 44/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9770
# Epoch 44: val_loss improved from 0.71660 to 0.71032, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.1690 - accuracy: 0.9770 - val_loss: 0.7103 - val_accuracy: 0.7997
# Epoch 45/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.9794
# Epoch 45: val_loss improved from 0.71032 to 0.70643, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.1562 - accuracy: 0.9794 - val_loss: 0.7064 - val_accuracy: 0.7966
# Epoch 46/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9784
# Epoch 46: val_loss improved from 0.70643 to 0.69980, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.1418 - accuracy: 0.9784 - val_loss: 0.6998 - val_accuracy: 0.7981
# Epoch 47/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9817
# Epoch 47: val_loss improved from 0.69980 to 0.69776, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.1426 - accuracy: 0.9817 - val_loss: 0.6978 - val_accuracy: 0.8028
# Epoch 48/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9767
# Epoch 48: val_loss improved from 0.69776 to 0.69605, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.1355 - accuracy: 0.9767 - val_loss: 0.6961 - val_accuracy: 0.8028
# Epoch 49/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9830
# Epoch 49: val_loss improved from 0.69605 to 0.68995, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.1327 - accuracy: 0.9830 - val_loss: 0.6900 - val_accuracy: 0.7997
# Epoch 50/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9840
# Epoch 50: val_loss improved from 0.68995 to 0.68490, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.1247 - accuracy: 0.9840 - val_loss: 0.6849 - val_accuracy: 0.7997
# Epoch 51/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9887
# Epoch 51: val_loss improved from 0.68490 to 0.68414, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.1131 - accuracy: 0.9887 - val_loss: 0.6841 - val_accuracy: 0.7997
# Epoch 52/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9893
# Epoch 52: val_loss improved from 0.68414 to 0.68082, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.1172 - accuracy: 0.9893 - val_loss: 0.6808 - val_accuracy: 0.7966
# Epoch 53/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9900
# Epoch 53: val_loss improved from 0.68082 to 0.67680, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.1069 - accuracy: 0.9900 - val_loss: 0.6768 - val_accuracy: 0.8075
# Epoch 54/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9880
# Epoch 54: val_loss improved from 0.67680 to 0.67149, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.1041 - accuracy: 0.9880 - val_loss: 0.6715 - val_accuracy: 0.8059
# Epoch 55/100
# 94/94 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9900
# Epoch 55: val_loss did not improve from 0.67149
# 94/94 [==============================] - 17s 177ms/step - loss: 0.1008 - accuracy: 0.9900 - val_loss: 0.6726 - val_accuracy: 0.7981
# Epoch 56/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9927
# Epoch 56: val_loss improved from 0.67149 to 0.66766, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 181ms/step - loss: 0.0917 - accuracy: 0.9927 - val_loss: 0.6677 - val_accuracy: 0.8059
# Epoch 57/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9907
# Epoch 57: val_loss improved from 0.66766 to 0.66334, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.0865 - accuracy: 0.9907 - val_loss: 0.6633 - val_accuracy: 0.8028
# Epoch 58/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9907
# Epoch 58: val_loss improved from 0.66334 to 0.66248, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.0879 - accuracy: 0.9907 - val_loss: 0.6625 - val_accuracy: 0.8044
# Epoch 59/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9920
# Epoch 59: val_loss improved from 0.66248 to 0.66049, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.0877 - accuracy: 0.9920 - val_loss: 0.6605 - val_accuracy: 0.8013
# Epoch 60/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.9927
# Epoch 60: val_loss improved from 0.66049 to 0.65839, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.0789 - accuracy: 0.9927 - val_loss: 0.6584 - val_accuracy: 0.8013
# Epoch 61/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9933
# Epoch 61: val_loss improved from 0.65839 to 0.65696, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 20s 204ms/step - loss: 0.0781 - accuracy: 0.9933 - val_loss: 0.6570 - val_accuracy: 0.7981
# Epoch 62/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9940
# Epoch 62: val_loss improved from 0.65696 to 0.65344, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.0752 - accuracy: 0.9940 - val_loss: 0.6534 - val_accuracy: 0.7966
# Epoch 63/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9933
# Epoch 63: val_loss improved from 0.65344 to 0.65085, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.0701 - accuracy: 0.9933 - val_loss: 0.6508 - val_accuracy: 0.7997
# Epoch 64/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9947
# Epoch 64: val_loss improved from 0.65085 to 0.64935, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 182ms/step - loss: 0.0728 - accuracy: 0.9947 - val_loss: 0.6494 - val_accuracy: 0.7966
# Epoch 65/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9933
# Epoch 65: val_loss did not improve from 0.64935
# 94/94 [==============================] - 17s 177ms/step - loss: 0.0719 - accuracy: 0.9933 - val_loss: 0.6519 - val_accuracy: 0.7981
# Epoch 66/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9937
# Epoch 66: val_loss improved from 0.64935 to 0.64748, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 19s 203ms/step - loss: 0.0675 - accuracy: 0.9937 - val_loss: 0.6475 - val_accuracy: 0.7997
# Epoch 67/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9940
# Epoch 67: val_loss improved from 0.64748 to 0.64449, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.0642 - accuracy: 0.9940 - val_loss: 0.6445 - val_accuracy: 0.8013
# Epoch 68/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9967
# Epoch 68: val_loss improved from 0.64449 to 0.64396, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.0570 - accuracy: 0.9967 - val_loss: 0.6440 - val_accuracy: 0.7966
# Epoch 69/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9947
# Epoch 69: val_loss improved from 0.64396 to 0.63972, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.0601 - accuracy: 0.9947 - val_loss: 0.6397 - val_accuracy: 0.7981
# Epoch 70/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9967
# Epoch 70: val_loss did not improve from 0.63972
# 94/94 [==============================] - 19s 198ms/step - loss: 0.0553 - accuracy: 0.9967 - val_loss: 0.6406 - val_accuracy: 0.7934
# Epoch 71/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9963
# Epoch 71: val_loss improved from 0.63972 to 0.63844, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.0550 - accuracy: 0.9963 - val_loss: 0.6384 - val_accuracy: 0.7997
# Epoch 72/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9957
# Epoch 72: val_loss improved from 0.63844 to 0.63664, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 19s 203ms/step - loss: 0.0512 - accuracy: 0.9957 - val_loss: 0.6366 - val_accuracy: 0.7981
# Epoch 73/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9973
# Epoch 73: val_loss improved from 0.63664 to 0.63461, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.0488 - accuracy: 0.9973 - val_loss: 0.6346 - val_accuracy: 0.7966
# Epoch 74/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9977
# Epoch 74: val_loss improved from 0.63461 to 0.63225, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.0517 - accuracy: 0.9977 - val_loss: 0.6322 - val_accuracy: 0.7997
# Epoch 75/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9980
# Epoch 75: val_loss improved from 0.63225 to 0.63041, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.0457 - accuracy: 0.9980 - val_loss: 0.6304 - val_accuracy: 0.7966
# Epoch 76/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9970
# Epoch 76: val_loss improved from 0.63041 to 0.62776, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 20s 204ms/step - loss: 0.0435 - accuracy: 0.9970 - val_loss: 0.6278 - val_accuracy: 0.7966
# Epoch 77/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9983
# Epoch 77: val_loss improved from 0.62776 to 0.62650, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.0440 - accuracy: 0.9983 - val_loss: 0.6265 - val_accuracy: 0.7981
# Epoch 78/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9967
# Epoch 78: val_loss improved from 0.62650 to 0.62421, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.0436 - accuracy: 0.9967 - val_loss: 0.6242 - val_accuracy: 0.8013
# Epoch 79/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9977
# Epoch 79: val_loss did not improve from 0.62421
# 94/94 [==============================] - 17s 177ms/step - loss: 0.0402 - accuracy: 0.9977 - val_loss: 0.6266 - val_accuracy: 0.7997
# Epoch 80/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9993
# Epoch 80: val_loss did not improve from 0.62421
# 94/94 [==============================] - 17s 177ms/step - loss: 0.0409 - accuracy: 0.9993 - val_loss: 0.6275 - val_accuracy: 0.7981
# Epoch 81/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9987
# Epoch 81: val_loss did not improve from 0.62421
# 94/94 [==============================] - 17s 176ms/step - loss: 0.0387 - accuracy: 0.9987 - val_loss: 0.6253 - val_accuracy: 0.7981
# Epoch 82/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9967
# Epoch 82: val_loss improved from 0.62421 to 0.62392, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.0409 - accuracy: 0.9967 - val_loss: 0.6239 - val_accuracy: 0.7966
# Epoch 83/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9977
# Epoch 83: val_loss improved from 0.62392 to 0.62356, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.0354 - accuracy: 0.9977 - val_loss: 0.6236 - val_accuracy: 0.7997
# Epoch 84/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9980
# Epoch 84: val_loss did not improve from 0.62356
# 94/94 [==============================] - 17s 177ms/step - loss: 0.0346 - accuracy: 0.9980 - val_loss: 0.6245 - val_accuracy: 0.7950
# Epoch 85/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9990
# Epoch 85: val_loss did not improve from 0.62356
# 94/94 [==============================] - 17s 176ms/step - loss: 0.0317 - accuracy: 0.9990 - val_loss: 0.6262 - val_accuracy: 0.7887
# Epoch 86/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9990
# Epoch 86: val_loss did not improve from 0.62356
# 94/94 [==============================] - 17s 178ms/step - loss: 0.0317 - accuracy: 0.9990 - val_loss: 0.6256 - val_accuracy: 0.7950
# Epoch 87/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9990
# Epoch 87: val_loss improved from 0.62356 to 0.62254, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.0343 - accuracy: 0.9990 - val_loss: 0.6225 - val_accuracy: 0.7966
# Epoch 88/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9987
# Epoch 88: val_loss improved from 0.62254 to 0.61643, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.0309 - accuracy: 0.9987 - val_loss: 0.6164 - val_accuracy: 0.7919
# Epoch 89/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9987
# Epoch 89: val_loss improved from 0.61643 to 0.61340, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 20s 204ms/step - loss: 0.0305 - accuracy: 0.9987 - val_loss: 0.6134 - val_accuracy: 0.7981
# Epoch 90/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9997
# Epoch 90: val_loss improved from 0.61340 to 0.61199, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 17s 182ms/step - loss: 0.0283 - accuracy: 0.9997 - val_loss: 0.6120 - val_accuracy: 0.7966
# Epoch 91/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9983
# Epoch 91: val_loss improved from 0.61199 to 0.60864, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.0281 - accuracy: 0.9983 - val_loss: 0.6086 - val_accuracy: 0.7981
# Epoch 92/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9997
# Epoch 92: val_loss improved from 0.60864 to 0.60813, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 184ms/step - loss: 0.0288 - accuracy: 0.9997 - val_loss: 0.6081 - val_accuracy: 0.7997
# Epoch 93/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9997
# Epoch 93: val_loss did not improve from 0.60813
# 94/94 [==============================] - 17s 177ms/step - loss: 0.0280 - accuracy: 0.9997 - val_loss: 0.6083 - val_accuracy: 0.8013
# Epoch 94/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9993
# Epoch 94: val_loss improved from 0.60813 to 0.60740, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 186ms/step - loss: 0.0238 - accuracy: 0.9993 - val_loss: 0.6074 - val_accuracy: 0.7997
# Epoch 95/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9990
# Epoch 95: val_loss improved from 0.60740 to 0.60672, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 0.0254 - accuracy: 0.9990 - val_loss: 0.6067 - val_accuracy: 0.7966
# Epoch 96/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9997
# Epoch 96: val_loss improved from 0.60672 to 0.60380, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 0.0240 - accuracy: 0.9997 - val_loss: 0.6038 - val_accuracy: 0.7997
# Epoch 97/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9990
# Epoch 97: val_loss did not improve from 0.60380
# 94/94 [==============================] - 17s 177ms/step - loss: 0.0231 - accuracy: 0.9990 - val_loss: 0.6054 - val_accuracy: 0.7950
# Epoch 98/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9990
# Epoch 98: val_loss improved from 0.60380 to 0.60214, saving model to /content/model/VGG16_test3.h5
# 94/94 [==============================] - 18s 185ms/step - loss: 0.0227 - accuracy: 0.9990 - val_loss: 0.6021 - val_accuracy: 0.7981
# Epoch 99/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9997
# Epoch 99: val_loss did not improve from 0.60214
# 94/94 [==============================] - 17s 178ms/step - loss: 0.0228 - accuracy: 0.9997 - val_loss: 0.6032 - val_accuracy: 0.7997
# Epoch 100/100
# 94/94 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9993
# Epoch 100: val_loss did not improve from 0.60214
# 94/94 [==============================] - 17s 177ms/step - loss: 0.0227 - accuracy: 0.9993 - val_loss: 0.6061 - val_accuracy: 0.8013

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 111s 5s/step - loss: 0.6338 - accuracy: 0.8064
# 21/21 [==============================] - 3s 139ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.84      0.96      0.90        50
#           Edgar_Degas       0.73      0.82      0.78        40
#      Vincent_van_Gogh       0.88      0.90      0.89       106
#        Albrecht_Dürer       0.76      0.71      0.74        45
#         Pablo_Picasso       0.92      0.65      0.76        37
#                Titian       0.78      0.79      0.79        67
#        Francisco_Goya       0.76      0.65      0.70        48
#          Marc_Chagall       0.77      0.73      0.75        51
# Pierre-Auguste_Renoir       0.70      0.88      0.78        40
#         Alfred_Sisley       0.81      0.77      0.79        39
#             Rembrandt       0.83      0.83      0.83       133
#
#              accuracy                           0.81       656
#             macro avg       0.80      0.79      0.79       656
#          weighted avg       0.81      0.81      0.80       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %%
plot_model_structure(model, "VGG16_Batch_Dropout")

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# We use the model with Dropout since it has the highest performances, we will make the same analysis unfreezing more layers simultaneously

# %%
model = models.load_model('/content/drive/Shareddrives/DeepLearning-ArtClassification/Models/VGG16Weights/Dropout.h5', compile=False)

# %% [markdown]
# ### Unfreezing of the last layer

# %%
trainable = False
for layer in model.get_layer("vgg16").layers:
  if layer.name == 'block5_conv3':
      trainable = True
  layer.trainable = trainable

model = model_compiler(model, 0.0001)

model.summary()
# Out:
# Model: "VGG16_Dropout"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_7   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_7 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  classifier_hidden_1 (Dense)  (None, 1024)             25691136
#
#  dropout_9 (Dropout)         (None, 1024)              0
#
#  classifier_hidden_2 (Dense)  (None, 512)              524800
#
#  dense_7 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 40,936,267
# Trainable params: 28,581,387
# Non-trainable params: 12,354,880
# _________________________________________________________________

# %%
model, history = model_executor(model, "Dropout_Last_Layer", training_images, val_images, 20, 5)
# Out:
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 0.3292 - accuracy: 0.9377
# Epoch 1: val_loss improved from inf to 1.91902, saving model to /content/model/Dropout_Last_Layer.h5
# 94/94 [==============================] - 561s 5s/step - loss: 0.3292 - accuracy: 0.9377 - val_loss: 1.9190 - val_accuracy: 0.7293
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9694
# Epoch 2: val_loss improved from 1.91902 to 1.46506, saving model to /content/model/Dropout_Last_Layer.h5
# 94/94 [==============================] - 17s 176ms/step - loss: 0.1360 - accuracy: 0.9694 - val_loss: 1.4651 - val_accuracy: 0.7919
# Epoch 3/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9777
# Epoch 3: val_loss did not improve from 1.46506
# 94/94 [==============================] - 16s 165ms/step - loss: 0.0855 - accuracy: 0.9777 - val_loss: 1.5568 - val_accuracy: 0.7825
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9847
# Epoch 4: val_loss did not improve from 1.46506
# 94/94 [==============================] - 16s 165ms/step - loss: 0.0803 - accuracy: 0.9847 - val_loss: 1.6470 - val_accuracy: 0.7919
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9840
# Epoch 5: val_loss improved from 1.46506 to 1.44995, saving model to /content/model/Dropout_Last_Layer.h5
# 94/94 [==============================] - 17s 182ms/step - loss: 0.0694 - accuracy: 0.9840 - val_loss: 1.4499 - val_accuracy: 0.7934
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9917
# Epoch 6: val_loss did not improve from 1.44995
# 94/94 [==============================] - 19s 193ms/step - loss: 0.0339 - accuracy: 0.9917 - val_loss: 1.6418 - val_accuracy: 0.8044
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9930
# Epoch 7: val_loss did not improve from 1.44995
# 94/94 [==============================] - 16s 171ms/step - loss: 0.0231 - accuracy: 0.9930 - val_loss: 1.4912 - val_accuracy: 0.8138
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9900
# Epoch 8: val_loss did not improve from 1.44995
# 94/94 [==============================] - 16s 170ms/step - loss: 0.0262 - accuracy: 0.9900 - val_loss: 1.5486 - val_accuracy: 0.7934
# Epoch 9/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9837
# Epoch 9: val_loss did not improve from 1.44995
# 94/94 [==============================] - 18s 192ms/step - loss: 0.0766 - accuracy: 0.9837 - val_loss: 1.6740 - val_accuracy: 0.7887
# Epoch 10/20
# 94/94 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9850
# Epoch 10: val_loss did not improve from 1.44995
# 94/94 [==============================] - 16s 168ms/step - loss: 0.0611 - accuracy: 0.9850 - val_loss: 1.6901 - val_accuracy: 0.7950

# %%
model = models.load_model('/content/drive/Shareddrives/DeepLearning-ArtClassification/Models/VGG16/Dropout_Last_Layer.h5')

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 103s 5s/step - loss: 1.4007 - accuracy: 0.7912
# 21/21 [==============================] - 3s 123ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.89      0.96      0.92        50
#           Edgar_Degas       0.91      0.78      0.84        40
#      Vincent_van_Gogh       0.83      0.96      0.89       106
#        Albrecht_Dürer       0.78      0.62      0.69        45
#         Pablo_Picasso       0.89      0.68      0.77        37
#                Titian       0.71      0.82      0.76        67
#        Francisco_Goya       0.76      0.54      0.63        48
#          Marc_Chagall       0.83      0.69      0.75        51
# Pierre-Auguste_Renoir       0.74      0.78      0.76        40
#         Alfred_Sisley       0.59      0.85      0.69        39
#             Rembrandt       0.81      0.79      0.80       133
#
#              accuracy                           0.79       656
#             macro avg       0.80      0.77      0.77       656
#          weighted avg       0.80      0.79      0.79       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %%
plot_model_structure(model, "Unfreeze_Last_Layer")

# %% [markdown]
# ### Unfreezing of the last layer  (classifier not trainable) learning_rate=0.0001

# %%
model = models.load_model('/content/drive/Shareddrives/DeepLearning-ArtClassification/Models/VGG16Weights/Dropout.h5', compile=False)

# %%
trainable = False
for layer in model.get_layer("vgg16").layers:
  if layer.name == 'block5_conv3':
      trainable = True
  layer.trainable = trainable

# %%
model.get_layer("classifier_hidden_1").trainable = False
model.get_layer("classifier_hidden_2").trainable = False
model.get_layer("dense_1").trainable = False

# %%
model = model_compiler(model, 0.0001)

model.summary()
# Out:
# Model: "VGG16_Dropout_Regularization"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  classifier_hidden_1 (Dense)  (None, 1024)             25691136
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  classifier_hidden_2 (Dense)  (None, 512)              524800
#
#  dense_1 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 40,936,267
# Trainable params: 2,359,808
# Non-trainable params: 38,576,459
# _________________________________________________________________

# %%
model, history = model_executor(model, "Dropout_Last_Layer_class_blocked", training_images, val_images, 20, 5)
# Out:
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 6.0913 - accuracy: 0.9008
# Epoch 1: val_loss improved from inf to 6.44847, saving model to /content/model/Dropout_Last_Layer_class_blocked.h5
# 94/94 [==============================] - 1400s 14s/step - loss: 6.0913 - accuracy: 0.9008 - val_loss: 6.4485 - val_accuracy: 0.8075
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 5.9856 - accuracy: 0.9411
# Epoch 2: val_loss did not improve from 6.44847
# 94/94 [==============================] - 17s 179ms/step - loss: 5.9856 - accuracy: 0.9411 - val_loss: 6.4582 - val_accuracy: 0.8216
# Epoch 3/20
# 94/94 [==============================] - ETA: 0s - loss: 5.9393 - accuracy: 0.9571
# Epoch 3: val_loss improved from 6.44847 to 6.39938, saving model to /content/model/Dropout_Last_Layer_class_blocked.h5
# 94/94 [==============================] - 17s 181ms/step - loss: 5.9393 - accuracy: 0.9571 - val_loss: 6.3994 - val_accuracy: 0.8185
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 5.9201 - accuracy: 0.9624
# Epoch 4: val_loss did not improve from 6.39938
# 94/94 [==============================] - 19s 195ms/step - loss: 5.9201 - accuracy: 0.9624 - val_loss: 6.4543 - val_accuracy: 0.8279
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 5.8980 - accuracy: 0.9707
# Epoch 5: val_loss did not improve from 6.39938
# 94/94 [==============================] - 17s 172ms/step - loss: 5.8980 - accuracy: 0.9707 - val_loss: 6.4268 - val_accuracy: 0.8388
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 5.8943 - accuracy: 0.9724
# Epoch 6: val_loss did not improve from 6.39938
# 94/94 [==============================] - 17s 174ms/step - loss: 5.8943 - accuracy: 0.9724 - val_loss: 6.4606 - val_accuracy: 0.8326
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 5.8814 - accuracy: 0.9767
# Epoch 7: val_loss did not improve from 6.39938
# 94/94 [==============================] - 17s 175ms/step - loss: 5.8814 - accuracy: 0.9767 - val_loss: 6.4307 - val_accuracy: 0.8326
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 5.8776 - accuracy: 0.9760
# Epoch 8: val_loss did not improve from 6.39938
# 94/94 [==============================] - 17s 174ms/step - loss: 5.8776 - accuracy: 0.9760 - val_loss: 6.4321 - val_accuracy: 0.8310

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 207s 10s/step - loss: 6.4616 - accuracy: 0.8095
# 21/21 [==============================] - 3s 134ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.98      0.94      0.96        50
#           Edgar_Degas       0.86      0.80      0.83        40
#      Vincent_van_Gogh       0.80      0.95      0.87       106
#        Albrecht_Dürer       0.82      0.69      0.75        45
#         Pablo_Picasso       0.82      0.73      0.77        37
#                Titian       0.82      0.75      0.78        67
#        Francisco_Goya       0.76      0.60      0.67        48
#          Marc_Chagall       0.81      0.67      0.73        51
# Pierre-Auguste_Renoir       0.72      0.82      0.77        40
#         Alfred_Sisley       0.74      0.67      0.70        39
#             Rembrandt       0.80      0.91      0.85       133
#
#              accuracy                           0.81       656
#             macro avg       0.81      0.78      0.79       656
#          weighted avg       0.81      0.81      0.81       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %%
plot_model_structure(model, "Unfreeze_Last_Layer")

# %% [markdown]
# ### Unfreezing of the last layer  (classifier not trainable) learning_rate=0.000001

# %%
model = models.load_model('/content/drive/Shareddrives/DeepLearning-ArtClassification/Models/VGG16Weights/Dropout.h5', compile=False)

# %%
trainable = False
for layer in model.get_layer("vgg16").layers:
  if layer.name == 'block5_conv3':
      trainable = True
  layer.trainable = trainable

# %%
model.get_layer("classifier_hidden_1").trainable = False
model.get_layer("classifier_hidden_2").trainable = False
model.get_layer("dense_1").trainable = False

# %%
model = model_compiler(model, 0.000001)
model.summary()
# Out:
# Model: "VGG16_Dropout_Regularization"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1   (None, 224, 224, 3)      0
#  (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  classifier_hidden_1 (Dense)  (None, 1024)             25691136
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  classifier_hidden_2 (Dense)  (None, 512)              524800
#
#  dense_1 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 40,936,267
# Trainable params: 2,359,808
# Non-trainable params: 38,576,459
# _________________________________________________________________

# %%
model, history = model_executor(model, "Dropout_Last_Layer_class_blocked_learning", training_images, val_images, 40, 3)
# Out:
# Epoch 1/40
# 94/94 [==============================] - ETA: 0s - loss: 6.1392 - accuracy: 0.8908
# Epoch 1: val_loss improved from inf to 6.50791, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 19s 184ms/step - loss: 6.1392 - accuracy: 0.8908 - val_loss: 6.5079 - val_accuracy: 0.7731
# Epoch 2/40
# 94/94 [==============================] - ETA: 0s - loss: 6.1138 - accuracy: 0.8915
# Epoch 2: val_loss improved from 6.50791 to 6.48625, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 180ms/step - loss: 6.1138 - accuracy: 0.8915 - val_loss: 6.4863 - val_accuracy: 0.7887
# Epoch 3/40
# 94/94 [==============================] - ETA: 0s - loss: 6.1027 - accuracy: 0.8968
# Epoch 3: val_loss improved from 6.48625 to 6.47044, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 178ms/step - loss: 6.1027 - accuracy: 0.8968 - val_loss: 6.4704 - val_accuracy: 0.7966
# Epoch 4/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0743 - accuracy: 0.9068
# Epoch 4: val_loss improved from 6.47044 to 6.46174, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 178ms/step - loss: 6.0743 - accuracy: 0.9068 - val_loss: 6.4617 - val_accuracy: 0.7997
# Epoch 5/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0796 - accuracy: 0.9035
# Epoch 5: val_loss improved from 6.46174 to 6.45444, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 19s 202ms/step - loss: 6.0796 - accuracy: 0.9035 - val_loss: 6.4544 - val_accuracy: 0.7966
# Epoch 6/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0628 - accuracy: 0.9131
# Epoch 6: val_loss improved from 6.45444 to 6.45057, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 178ms/step - loss: 6.0628 - accuracy: 0.9131 - val_loss: 6.4506 - val_accuracy: 0.7981
# Epoch 7/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0654 - accuracy: 0.9121
# Epoch 7: val_loss improved from 6.45057 to 6.44769, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 19s 201ms/step - loss: 6.0654 - accuracy: 0.9121 - val_loss: 6.4477 - val_accuracy: 0.7981
# Epoch 8/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0659 - accuracy: 0.9075
# Epoch 8: val_loss improved from 6.44769 to 6.44579, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 179ms/step - loss: 6.0659 - accuracy: 0.9075 - val_loss: 6.4458 - val_accuracy: 0.7966
# Epoch 9/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0458 - accuracy: 0.9224
# Epoch 9: val_loss improved from 6.44579 to 6.44525, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 19s 203ms/step - loss: 6.0458 - accuracy: 0.9224 - val_loss: 6.4453 - val_accuracy: 0.8013
# Epoch 10/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0478 - accuracy: 0.9181
# Epoch 10: val_loss improved from 6.44525 to 6.44281, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 178ms/step - loss: 6.0478 - accuracy: 0.9181 - val_loss: 6.4428 - val_accuracy: 0.8028
# Epoch 11/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0455 - accuracy: 0.9244
# Epoch 11: val_loss improved from 6.44281 to 6.44063, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 179ms/step - loss: 6.0455 - accuracy: 0.9244 - val_loss: 6.4406 - val_accuracy: 0.8013
# Epoch 12/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0402 - accuracy: 0.9178
# Epoch 12: val_loss improved from 6.44063 to 6.43768, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 180ms/step - loss: 6.0402 - accuracy: 0.9178 - val_loss: 6.4377 - val_accuracy: 0.8059
# Epoch 13/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0379 - accuracy: 0.9231
# Epoch 13: val_loss improved from 6.43768 to 6.43736, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 180ms/step - loss: 6.0379 - accuracy: 0.9231 - val_loss: 6.4374 - val_accuracy: 0.8044
# Epoch 14/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0411 - accuracy: 0.9168
# Epoch 14: val_loss improved from 6.43736 to 6.43610, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 18s 180ms/step - loss: 6.0411 - accuracy: 0.9168 - val_loss: 6.4361 - val_accuracy: 0.8075
# Epoch 15/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0404 - accuracy: 0.9214
# Epoch 15: val_loss improved from 6.43610 to 6.43452, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 180ms/step - loss: 6.0404 - accuracy: 0.9214 - val_loss: 6.4345 - val_accuracy: 0.8075
# Epoch 16/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0240 - accuracy: 0.9288
# Epoch 16: val_loss improved from 6.43452 to 6.43203, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 6.0240 - accuracy: 0.9288 - val_loss: 6.4320 - val_accuracy: 0.8059
# Epoch 17/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0369 - accuracy: 0.9248
# Epoch 17: val_loss improved from 6.43203 to 6.43033, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 180ms/step - loss: 6.0369 - accuracy: 0.9248 - val_loss: 6.4303 - val_accuracy: 0.8075
# Epoch 18/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0270 - accuracy: 0.9248
# Epoch 18: val_loss improved from 6.43033 to 6.42980, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 19s 201ms/step - loss: 6.0270 - accuracy: 0.9248 - val_loss: 6.4298 - val_accuracy: 0.8059
# Epoch 19/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0253 - accuracy: 0.9311
# Epoch 19: val_loss improved from 6.42980 to 6.42910, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 180ms/step - loss: 6.0253 - accuracy: 0.9311 - val_loss: 6.4291 - val_accuracy: 0.8059
# Epoch 20/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0329 - accuracy: 0.9228
# Epoch 20: val_loss improved from 6.42910 to 6.42732, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 181ms/step - loss: 6.0329 - accuracy: 0.9228 - val_loss: 6.4273 - val_accuracy: 0.8091
# Epoch 21/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0033 - accuracy: 0.9334
# Epoch 21: val_loss did not improve from 6.42732
# 94/94 [==============================] - 19s 197ms/step - loss: 6.0033 - accuracy: 0.9334 - val_loss: 6.4282 - val_accuracy: 0.8075
# Epoch 22/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0205 - accuracy: 0.9261
# Epoch 22: val_loss did not improve from 6.42732
# 94/94 [==============================] - 17s 173ms/step - loss: 6.0205 - accuracy: 0.9261 - val_loss: 6.4277 - val_accuracy: 0.8075
# Epoch 23/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0153 - accuracy: 0.9274
# Epoch 23: val_loss improved from 6.42732 to 6.42709, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 19s 201ms/step - loss: 6.0153 - accuracy: 0.9274 - val_loss: 6.4271 - val_accuracy: 0.8106
# Epoch 24/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0053 - accuracy: 0.9321
# Epoch 24: val_loss improved from 6.42709 to 6.42534, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 180ms/step - loss: 6.0053 - accuracy: 0.9321 - val_loss: 6.4253 - val_accuracy: 0.8106
# Epoch 25/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0027 - accuracy: 0.9318
# Epoch 25: val_loss did not improve from 6.42534
# 94/94 [==============================] - 17s 177ms/step - loss: 6.0027 - accuracy: 0.9318 - val_loss: 6.4254 - val_accuracy: 0.8106
# Epoch 26/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0004 - accuracy: 0.9368
# Epoch 26: val_loss did not improve from 6.42534
# 94/94 [==============================] - 17s 174ms/step - loss: 6.0004 - accuracy: 0.9368 - val_loss: 6.4254 - val_accuracy: 0.8122
# Epoch 27/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0040 - accuracy: 0.9364
# Epoch 27: val_loss improved from 6.42534 to 6.42459, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 182ms/step - loss: 6.0040 - accuracy: 0.9364 - val_loss: 6.4246 - val_accuracy: 0.8106
# Epoch 28/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0020 - accuracy: 0.9391
# Epoch 28: val_loss improved from 6.42459 to 6.42324, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 178ms/step - loss: 6.0020 - accuracy: 0.9391 - val_loss: 6.4232 - val_accuracy: 0.8091
# Epoch 29/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0061 - accuracy: 0.9344
# Epoch 29: val_loss did not improve from 6.42324
# 94/94 [==============================] - 17s 174ms/step - loss: 6.0061 - accuracy: 0.9344 - val_loss: 6.4240 - val_accuracy: 0.8122
# Epoch 30/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0019 - accuracy: 0.9321
# Epoch 30: val_loss improved from 6.42324 to 6.42224, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 18s 182ms/step - loss: 6.0019 - accuracy: 0.9321 - val_loss: 6.4222 - val_accuracy: 0.8122
# Epoch 31/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9960 - accuracy: 0.9391
# Epoch 31: val_loss improved from 6.42224 to 6.42120, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 181ms/step - loss: 5.9960 - accuracy: 0.9391 - val_loss: 6.4212 - val_accuracy: 0.8138
# Epoch 32/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9790 - accuracy: 0.9434
# Epoch 32: val_loss improved from 6.42120 to 6.42077, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 180ms/step - loss: 5.9790 - accuracy: 0.9434 - val_loss: 6.4208 - val_accuracy: 0.8153
# Epoch 33/40
# 94/94 [==============================] - ETA: 0s - loss: 6.0050 - accuracy: 0.9338
# Epoch 33: val_loss improved from 6.42077 to 6.41873, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 179ms/step - loss: 6.0050 - accuracy: 0.9338 - val_loss: 6.4187 - val_accuracy: 0.8153
# Epoch 34/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9859 - accuracy: 0.9441
# Epoch 34: val_loss improved from 6.41873 to 6.41679, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 19s 202ms/step - loss: 5.9859 - accuracy: 0.9441 - val_loss: 6.4168 - val_accuracy: 0.8153
# Epoch 35/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9908 - accuracy: 0.9444
# Epoch 35: val_loss did not improve from 6.41679
# 94/94 [==============================] - 17s 174ms/step - loss: 5.9908 - accuracy: 0.9444 - val_loss: 6.4173 - val_accuracy: 0.8138
# Epoch 36/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9887 - accuracy: 0.9401
# Epoch 36: val_loss did not improve from 6.41679
# 94/94 [==============================] - 17s 175ms/step - loss: 5.9887 - accuracy: 0.9401 - val_loss: 6.4177 - val_accuracy: 0.8122
# Epoch 37/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9963 - accuracy: 0.9331
# Epoch 37: val_loss improved from 6.41679 to 6.41553, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 18s 183ms/step - loss: 5.9963 - accuracy: 0.9331 - val_loss: 6.4155 - val_accuracy: 0.8169
# Epoch 38/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9887 - accuracy: 0.9471
# Epoch 38: val_loss improved from 6.41553 to 6.41455, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 17s 179ms/step - loss: 5.9887 - accuracy: 0.9471 - val_loss: 6.4145 - val_accuracy: 0.8153
# Epoch 39/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9846 - accuracy: 0.9394
# Epoch 39: val_loss improved from 6.41455 to 6.41426, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 19s 202ms/step - loss: 5.9846 - accuracy: 0.9394 - val_loss: 6.4143 - val_accuracy: 0.8169
# Epoch 40/40
# 94/94 [==============================] - ETA: 0s - loss: 5.9891 - accuracy: 0.9441
# Epoch 40: val_loss did not improve from 6.41426
# 94/94 [==============================] - 17s 174ms/step - loss: 5.9891 - accuracy: 0.9441 - val_loss: 6.4150 - val_accuracy: 0.8169

# %%
model = models.load_model('/content/drive/Shareddrives/DeepLearning-ArtClassification/Models/VGG16/Dropout_Last_Layer_class_blocked_learning.h5')

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 3s 133ms/step - loss: 6.4943 - accuracy: 0.7896
# 21/21 [==============================] - 3s 135ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.87      0.96      0.91        50
#           Edgar_Degas       0.78      0.80      0.79        40
#      Vincent_van_Gogh       0.79      0.91      0.84       106
#        Albrecht_Dürer       0.85      0.64      0.73        45
#         Pablo_Picasso       0.72      0.78      0.75        37
#                Titian       0.84      0.70      0.76        67
#        Francisco_Goya       0.77      0.62      0.69        48
#          Marc_Chagall       0.74      0.67      0.70        51
# Pierre-Auguste_Renoir       0.73      0.88      0.80        40
#         Alfred_Sisley       0.71      0.74      0.72        39
#             Rembrandt       0.81      0.82      0.82       133
#
#              accuracy                           0.79       656
#             macro avg       0.78      0.78      0.78       656
#          weighted avg       0.79      0.79      0.79       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %% [markdown]
# ### Unfreezing of the last layer  (classifier not trainable) learning_rate=0.000001

# %%
model = models.load_model('/content/drive/Shareddrives/DeepLearning-ArtClassification/Models/VGG16Weights/Dropout.h5', compile=False)

# %%
trainable = False
for layer in model.get_layer("vgg16").layers:
  if layer.name == 'block5_conv3':
      trainable = True
  layer.trainable = trainable

# %%
model.get_layer("classifier_hidden_1").trainable = False
model.get_layer("classifier_hidden_2").trainable = False
model.get_layer("dense_1").trainable = False

# %%
model = model_compiler(model, 0.000001)
model.summary()

# %%
model, history = model_executor(model, "Dropout_Last_Layer_class_blocked_learning", training_images, val_images, 40, 3)
# Out:
# Epoch 1/20
# 94/94 [==============================] - ETA: 0s - loss: 4.7262 - accuracy: 0.8928
# Epoch 1: val_loss improved from inf to 4.35508, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 475s 5s/step - loss: 4.7262 - accuracy: 0.8928 - val_loss: 4.3551 - val_accuracy: 0.7950
# Epoch 2/20
# 94/94 [==============================] - ETA: 0s - loss: 3.7992 - accuracy: 0.9081
# Epoch 2: val_loss improved from 4.35508 to 4.09487, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 243ms/step - loss: 3.7992 - accuracy: 0.9081 - val_loss: 4.0949 - val_accuracy: 0.7950
# Epoch 3/20
# 94/94 [==============================] - ETA: 0s - loss: 3.6640 - accuracy: 0.9055
# Epoch 3: val_loss improved from 4.09487 to 4.01060, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 238ms/step - loss: 3.6640 - accuracy: 0.9055 - val_loss: 4.0106 - val_accuracy: 0.8028
# Epoch 4/20
# 94/94 [==============================] - ETA: 0s - loss: 3.5707 - accuracy: 0.9258
# Epoch 4: val_loss improved from 4.01060 to 3.94693, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 238ms/step - loss: 3.5707 - accuracy: 0.9258 - val_loss: 3.9469 - val_accuracy: 0.8044
# Epoch 5/20
# 94/94 [==============================] - ETA: 0s - loss: 3.5044 - accuracy: 0.9298
# Epoch 5: val_loss improved from 3.94693 to 3.88946, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 240ms/step - loss: 3.5044 - accuracy: 0.9298 - val_loss: 3.8895 - val_accuracy: 0.8028
# Epoch 6/20
# 94/94 [==============================] - ETA: 0s - loss: 3.4534 - accuracy: 0.9261
# Epoch 6: val_loss improved from 3.88946 to 3.83871, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 240ms/step - loss: 3.4534 - accuracy: 0.9261 - val_loss: 3.8387 - val_accuracy: 0.8059
# Epoch 7/20
# 94/94 [==============================] - ETA: 0s - loss: 3.3912 - accuracy: 0.9314
# Epoch 7: val_loss improved from 3.83871 to 3.79114, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 242ms/step - loss: 3.3912 - accuracy: 0.9314 - val_loss: 3.7911 - val_accuracy: 0.8059
# Epoch 8/20
# 94/94 [==============================] - ETA: 0s - loss: 3.3287 - accuracy: 0.9361
# Epoch 8: val_loss improved from 3.79114 to 3.74791, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 236ms/step - loss: 3.3287 - accuracy: 0.9361 - val_loss: 3.7479 - val_accuracy: 0.8028
# Epoch 9/20
# 94/94 [==============================] - ETA: 0s - loss: 3.2889 - accuracy: 0.9421
# Epoch 9: val_loss improved from 3.74791 to 3.70415, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 24s 247ms/step - loss: 3.2889 - accuracy: 0.9421 - val_loss: 3.7041 - val_accuracy: 0.8044
# Epoch 10/20
# 94/94 [==============================] - ETA: 0s - loss: 3.2283 - accuracy: 0.9477
# Epoch 10: val_loss improved from 3.70415 to 3.66291, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 241ms/step - loss: 3.2283 - accuracy: 0.9477 - val_loss: 3.6629 - val_accuracy: 0.8075
# Epoch 11/20
# 94/94 [==============================] - ETA: 0s - loss: 3.1925 - accuracy: 0.9434
# Epoch 11: val_loss improved from 3.66291 to 3.62215, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 22s 234ms/step - loss: 3.1925 - accuracy: 0.9434 - val_loss: 3.6222 - val_accuracy: 0.8091
# Epoch 12/20
# 94/94 [==============================] - ETA: 0s - loss: 3.1409 - accuracy: 0.9511
# Epoch 12: val_loss improved from 3.62215 to 3.58382, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 243ms/step - loss: 3.1409 - accuracy: 0.9511 - val_loss: 3.5838 - val_accuracy: 0.8185
# Epoch 13/20
# 94/94 [==============================] - ETA: 0s - loss: 3.1195 - accuracy: 0.9437
# Epoch 13: val_loss improved from 3.58382 to 3.54571, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 242ms/step - loss: 3.1195 - accuracy: 0.9437 - val_loss: 3.5457 - val_accuracy: 0.8153
# Epoch 14/20
# 94/94 [==============================] - ETA: 0s - loss: 3.0761 - accuracy: 0.9481
# Epoch 14: val_loss improved from 3.54571 to 3.51259, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 22s 235ms/step - loss: 3.0761 - accuracy: 0.9481 - val_loss: 3.5126 - val_accuracy: 0.8153
# Epoch 15/20
# 94/94 [==============================] - ETA: 0s - loss: 3.0299 - accuracy: 0.9497
# Epoch 15: val_loss improved from 3.51259 to 3.47794, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 246ms/step - loss: 3.0299 - accuracy: 0.9497 - val_loss: 3.4779 - val_accuracy: 0.8185
# Epoch 16/20
# 94/94 [==============================] - ETA: 0s - loss: 2.9887 - accuracy: 0.9531
# Epoch 16: val_loss improved from 3.47794 to 3.44591, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 236ms/step - loss: 2.9887 - accuracy: 0.9531 - val_loss: 3.4459 - val_accuracy: 0.8216
# Epoch 17/20
# 94/94 [==============================] - ETA: 0s - loss: 2.9545 - accuracy: 0.9517
# Epoch 17: val_loss improved from 3.44591 to 3.41161, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 238ms/step - loss: 2.9545 - accuracy: 0.9517 - val_loss: 3.4116 - val_accuracy: 0.8247
# Epoch 18/20
# 94/94 [==============================] - ETA: 0s - loss: 2.9268 - accuracy: 0.9531
# Epoch 18: val_loss improved from 3.41161 to 3.37833, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 243ms/step - loss: 2.9268 - accuracy: 0.9531 - val_loss: 3.3783 - val_accuracy: 0.8247
# Epoch 19/20
# 94/94 [==============================] - ETA: 0s - loss: 2.8708 - accuracy: 0.9627
# Epoch 19: val_loss improved from 3.37833 to 3.34918, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 22s 231ms/step - loss: 2.8708 - accuracy: 0.9627 - val_loss: 3.3492 - val_accuracy: 0.8232
# Epoch 20/20
# 94/94 [==============================] - ETA: 0s - loss: 2.8487 - accuracy: 0.9607
# Epoch 20: val_loss improved from 3.34918 to 3.31887, saving model to /content/model/Dropout_Last_Layer_class_blocked_learning.h5
# 94/94 [==============================] - 23s 242ms/step - loss: 2.8487 - accuracy: 0.9607 - val_loss: 3.3189 - val_accuracy: 0.8216

# %%
model = models.load_model('/content/drive/Shareddrives/DeepLearning-ArtClassification/Models/VGG16/Dropout_Last_Layer_class_blocked_learning.h5')

# %%
plot_train_history(history)

# %%
pred_labels = model_evaluator(model, test_images)
# Out:
# 21/21 [==============================] - 87s 4s/step - loss: 3.3822 - accuracy: 0.7973
# 21/21 [==============================] - 4s 173ms/step
#                        precision    recall  f1-score   support
#
#          Paul_Gauguin       0.87      0.96      0.91        50
#           Edgar_Degas       0.82      0.80      0.81        40
#      Vincent_van_Gogh       0.78      0.91      0.84       106
#        Albrecht_Dürer       0.81      0.67      0.73        45
#         Pablo_Picasso       0.82      0.76      0.79        37
#                Titian       0.77      0.73      0.75        67
#        Francisco_Goya       0.76      0.65      0.70        48
#          Marc_Chagall       0.82      0.65      0.73        51
# Pierre-Auguste_Renoir       0.74      0.88      0.80        40
#         Alfred_Sisley       0.68      0.72      0.70        39
#             Rembrandt       0.84      0.85      0.84       133
#
#              accuracy                           0.80       656
#             macro avg       0.79      0.78      0.78       656
#          weighted avg       0.80      0.80      0.79       656

# %%
confusion_matrix_maker(model, test_images, pred_labels)

# %%
plot_model_structure(model, "Unfreeze_Last_Layer")
